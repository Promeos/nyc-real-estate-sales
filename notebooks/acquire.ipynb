# %% [markdown]
# # Data Acquisition

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('../data/nyc_data.xlsx')

# %%
df.shape
# Out:
# (65597, 21)

# %%
df.head()
# Out:
#    BOROUGH\n NEIGHBORHOOD\n                    BUILDING CLASS CATEGORY\n  \
# 0          1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1          1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2          1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3          1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4          1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
#
#   TAX CLASS AS OF FINAL ROLL 18/19  BLOCK\n  LOT\n EASE-MENT\n  \
# 0                                2      375     28
# 1                                2      385     36
# 2                               2A      392      5
# 3                               2A      392      6
# 4                                2      400     61
#
#   BUILDING CLASS AS OF FINAL ROLL 18/19              ADDRESS\n  \
# 0                                    C4    738 EAST 6TH STREET
# 1                                    C7            27 AVENUE C
# 2                                    C2           151 AVENUE B
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65597 entries, 0 to 65596
# Data columns (total 21 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   BOROUGH
#                                65597 non-null  int64
#  1   NEIGHBORHOOD
#                           65597 non-null  object
#  2   BUILDING CLASS CATEGORY
#                65597 non-null  object
#  3   TAX CLASS AS OF FINAL ROLL 18/19       65418 non-null  object
#  4   BLOCK
#                                  65597 non-null  int64
#  5   LOT
#                                    65597 non-null  int64
#  6   EASE-MENT
#                              18642 non-null  object
#  7   BUILDING CLASS AS OF FINAL ROLL 18/19  65418 non-null  object
#  8   ADDRESS
#                                65597 non-null  object
#  9   APARTMENT NUMBER
#                       40376 non-null  object
#  10  ZIP CODE
# ...

# %%
df.describe().T
# Out:
#                                count          mean           std   min  \
# BOROUGH\n                    65597.0  1.000000e+00  0.000000e+00   1.0
# BLOCK\n                      65597.0  1.118167e+03  5.302200e+02   2.0
# LOT\n                        65597.0  7.556837e+02  9.194700e+02   1.0
# ZIP CODE\n                   65597.0  1.000154e+04  5.331730e+02   0.0
# RESIDENTIAL UNITS\n          52157.0  2.520716e+00  4.212848e+01   0.0
# COMMERCIAL UNITS\n           47199.0  5.105405e-01  6.828389e+00 -16.0
# TOTAL UNITS\n                52595.0  3.011465e+00  4.271716e+01   0.0
# LAND SQUARE FEET\n           46761.0  2.037477e+03  1.579207e+04   0.0
# GROSS SQUARE FEET\n          46761.0  5.693456e+03  6.535126e+04   0.0
# YEAR BUILT\n                 62182.0  1.804539e+03  5.184475e+02   0.0
# TAX CLASS AT TIME OF SALE\n  65597.0  2.115142e+00  5.278587e-01   1.0
# SALE PRICE\n                 65597.0  3.168155e+06  2.431457e+07   0.0
#
# ...

# %%
df.describe(exclude='number', datetime_is_numeric=True).T
# Out:
#                                        count unique  \
# NEIGHBORHOOD\n                         65597     39
# BUILDING CLASS CATEGORY\n              65597     87
# TAX CLASS AS OF FINAL ROLL 18/19       65418     12
# EASE-MENT\n                            18642      1
# BUILDING CLASS AS OF FINAL ROLL 18/19  65418    151
# ADDRESS\n                              65597  47327
# APARTMENT NUMBER\n                     40376   5985
# BUILDING CLASS AT TIME OF SALE\n       65597    150
# SALE DATE\n                            65597    NaN
#
#                                                                    top   freq  \
# NEIGHBORHOOD\n                                 UPPER EAST SIDE (59-79)   6592
# BUILDING CLASS CATEGORY\n              13 CONDOS - ELEVATOR APARTMENTS  18866
# TAX CLASS AS OF FINAL ROLL 18/19                                     2  40435
# EASE-MENT\n                                                             18642
# ...

# %%
df.isna().sum()[df.isna().sum() > 0]
# Out:
# TAX CLASS AS OF FINAL ROLL 18/19           179
# EASE-MENT\n                              46955
# BUILDING CLASS AS OF FINAL ROLL 18/19      179
# APARTMENT NUMBER\n                       25221
# RESIDENTIAL UNITS\n                      13440
# COMMERCIAL UNITS\n                       18398
# TOTAL UNITS\n                            13002
# LAND SQUARE FEET\n                       18836
# GROSS SQUARE FEET\n                      18836
# YEAR BUILT\n                              3415
# dtype: int64

# %%
# Rename columns
df.columns = df.columns.str.replace('\n', '')
df.columns = df.columns.str.lower()
df.columns = [column.replace(' ', '_') for column in df.columns]

# %%
df.drop(columns = ['tax_class_as_of_final_roll_18/19',
                   'ease-ment',
                   'building_class_as_of_final_roll_18/19',
                   'apartment_number',
                   'residential_units',
                   'commercial_units'],
       inplace=True)

# %%
df.head()
# Out:
#    borough   neighborhood                      building_class_category  block  \
# 0        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 375
# 1        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 385
# 2        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 392
# 3        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 392
# 4        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                 400
#
#    lot                address  zip_code  total_units  land_square_feet  \
# 0   28    738 EAST 6TH STREET     10009         11.0            1750.0
# 1   36            27 AVENUE C     10009         25.0            2650.0
# 2    5           151 AVENUE B     10009          5.0            2139.0
# 3    6           153 AVENUE B     10009          5.0            1633.0
# 4   61  193 EAST 4TH   STREET     10009         12.0            2388.0
#
#    gross_square_feet  year_built  tax_class_at_time_of_sale  \
# ...

# %%
df.borough.value_counts()
# Out:
# 1    65597
# Name: borough, dtype: int64

# %%
df = df.dropna()
df = df.

# %%
sns.set_context('talk')
df.hist(figsize=(16, 16), bins=30);
plt.tight_layout()

# %%
nonnumeric_data = df.select_dtypes(exclude='number')

nonnumeric_data.columns
# Out:
# Index(['neighborhood', 'building_class_category', 'address',
#        'building_class_at_time_of_sale', 'sale_date'],
#       dtype='object')

# %%
sns.set_context('talk')
plt.figure(figsize=(10, 10))
sns.countplot(data=nonnumeric_data, y=f'neighborhood')
plt.tight_layout();

# %%
nonnumeric_data.building_class_category.value_counts().nlargest(20).plot.barh(figsize=(13, 7));

# %%
nonnumeric_data.address.value_counts().nlargest(20).plot.barh(figsize=(13, 7));

# %%
nonnumeric_data.building_class_at_time_of_sale.value_counts().nlargest(20).plot.barh(figsize=(13, 7));

# %%
sns.set_context('talk')
plt.figure(figsize=(8, 6))
sns.countplot(data=nonnumeric_data, x=nonnumeric_data.sale_date.dt.year)
plt.tight_layout();
